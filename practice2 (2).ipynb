# %% [markdown]
# # Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# The code above is used to import necessary libraies needed for the project. They would aid our data cleaning and visualization process. Hence, it is most suitable to be imported before any work is done concerning the project.

# %% [markdown]
# # Importing our Data

# %%
path = r"C:\Users\GBOLAHAN\Desktop\AileadTech Python class\CardioGoodFitness-1.csv"
df = pd.read_csv(path)

# %% [markdown]
# The code above is used to read our Data set into Jupyter noteook for further process. The Dataset now has a variable name known as df. So we can refer to our Data by just calling the df in our jupyter notebook.

# %%
df
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %% [markdown]
# The variable name df which refers to the Dataset name as seen above provides an overview of the Dataset. It shows the total observation and features in the Data sets. We have 180 observations and 9 feautures in this Dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# The code above df.info() gives a first hand information of the Dataset in their respective Data Structure format including other details as well as the features contining blanks.

# %%
df.shape
# Out:
# (180, 9)

# %% [markdown]
# The code above df.shape talks about the shape of the Dataset with its respective rows and columns.

# %%
df.dtypes
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %% [markdown]
# The code above df.dtypes provides the Data Structure format including of the Dataset.

# %%
df.describe(include="all").T
# Out:
#                count unique        top freq          mean           std  \
# Product          180      3      TM195   80           NaN           NaN
# Age            180.0    NaN        NaN  NaN     28.788889      6.943498
# Gender           180      2       Male  104           NaN           NaN
# Education      180.0    NaN        NaN  NaN     15.572222      1.617055
# MaritalStatus    180      2  Partnered  107           NaN           NaN
# Usage          180.0    NaN        NaN  NaN      3.455556      1.084797
# Fitness        180.0    NaN        NaN  NaN      3.311111      0.958869
# Income         180.0    NaN        NaN  NaN  53719.577778  16506.684226
# Miles          180.0    NaN        NaN  NaN    103.194444     51.863605
#
#                    min       25%      50%      75%       max
# Product            NaN       NaN      NaN      NaN       NaN
# Age               18.0      24.0     26.0     33.0      50.0
# Gender             NaN       NaN      NaN      NaN       NaN
# ...

# %% [markdown]
# The code above df.describe(include="all").T describes the numerical Data as regarding their mean std, min. 25%, 50%, 75% and max values.

# %%
df.corr()
# Out:
# C:\Users\GBOLAHAN\AppData\Local\Temp\ipykernel_15288\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %% [markdown]
# The code above shows the correlation between two numerical features. This tells us if there is any relationship between these features in our Dataset. The relatonship could be positive(closer to 1 or 1) or negative(closer to -1 0r -1) or independent(showing no relationship (0)).

# %% [markdown]
# # Checking for Missing Values

# %%
df.isna().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# The code above df.isna().sum() helps to check for missing values in our Dataset by summing all the blanks and Na's in the respective features we have. As we can see above, there are no missing values in our Dataset.

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %% [markdown]
# The code above df.head() gives an overview of the the first 5 Dataset from the top if the numbers to display are not stated. This helps to understand the Dataset very well and check for abnomalies.

# %%
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %% [markdown]
# The code above df.tail() gives an overview of the the first 5 Dataset from the bottom if the numbers to display are not stated. This helps to understand the Dataset very well and check for abnomalies.

# %%
df.sample(n=10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 16    TM195   23  Female         14        Single      2        3   34110
# 154   TM798   25    Male         18     Partnered      6        4   70966
# 99    TM498   25    Male         16     Partnered      2        2   52302
# 151   TM798   25    Male         16     Partnered      4        4   62251
# 19    TM195   23  Female         15     Partnered      2        2   34110
# 13    TM195   22  Female         14        Single      3        3   35247
# 160   TM798   27    Male         18        Single      4        3   88396
# 167   TM798   30  Female         16     Partnered      6        5   90886
# 168   TM798   30    Male         18     Partnered      5        4  103336
# 175   TM798   40    Male         21        Single      6        5   83416
#
#      Miles
# 16     103
# 154    180
# 99      42
# 151    160
# 19      38
# 13      75
# 160    100
# 167    280
# 168    160
# 175    200

# %% [markdown]
# The code above df.sample() provides a sampling overview of the the Dataset if the numbers to display are not stated. This helps to understand the Dataset very well and check for abnomalies.

# %% [markdown]
# # Univariate Data Analysis

# %% [markdown]
# Our Univariate Data Analysis will provide the distribution of our individual features in our Dataset. This brings about initial understanding of our Dataset.

# %%
df.nunique()
# Out:
# Product           3
# Age              32
# Gender            2
# Education         8
# MaritalStatus     2
# Usage             6
# Fitness           5
# Income           62
# Miles            37
# dtype: int64

# %%
The code above df.nunique provides the counts of the unique values or characters in the individual features.

# %%
def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %% [markdown]
# The code below defines the function for our graphs that helps to return percentage on our countplot graph.

# %% [markdown]
# # Graph showing Product Visualization

# %%
labeled_barplot(df, "Product", perc=True, n=None);

# %%
df.Product.value_counts()
# Out:
# TM195    80
# TM498    60
# TM798    40
# Name: Product, dtype: int64

# %% [markdown]
# The Product graph above shows the 3 respective products given their percentage. As observed, Product (TM195) haS the highest percentage with about (44.4%) while Product (TM798) haS the lowest percentage with about (22.2%). This tells us more that Product TM195 was highly used by customers over the remaining products.

# %% [markdown]
# # Graph showing Age Visualization

# %%
sns.histplot(x="Age", data=df, kde=True);

# %%
df.Age.mean()
# Out:
# 28.788888888888888

# %%
df.Age.median()
# Out:
# 26.0

# %%
df.Age.mode()
# Out:
# 0    25
# Name: Age, dtype: int64

# %% [markdown]
# The Age graph above explains the age distribution of customers. As seen, the most prevalent Age range of customers fall within Age 23 to Age 26 with Age 25 having the highest number of users for the products. Observation made it clearer by showing that people of younger age tends to use the product the more. Tey fall within the range of 19 to 30

# %% [markdown]
# # Graph showing Gender Visualization

# %%
labeled_barplot(df, "Gender", perc=True, n=None);

# %%
df.Gender.value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %% [markdown]
# The Gender graph above explains the product distribution of customers based on Gender. It shows both gender actively use the product. It clearly explains that the Male gender with about 57.8% use the product more than the female gender.

# %% [markdown]
# # Graph showing Education Visualization

# %%
labeled_barplot(df, "Education", perc=True, n=None);

# %%
df.Education.value_counts()
# please comment
# Out:
# 16    85
# 14    55
# 18    23
# 15     5
# 13     5
# 12     3
# 21     3
# 20     1
# Name: Education, dtype: int64

# %% [markdown]
# The Education graph above explains the product distribution of customers based on their Education. Educations explains the numer of years the customers have been aware about the product. As observed from the graph, the educated people with 16 years of knowledge tends to be the one that use the product the most. Also, the educated people with 14 years also tends to use the products well while the educated people within 20 and 21 tends to be less educated about the product. It provides us with an overview that the customers that have known the products for a very long time offset the numbers of customers using the products around that Education range.

# %% [markdown]
# # Graph showing Marital Status Visualization

# %%
labeled_barplot(df, "MaritalStatus", perc=True, n=None);

# %%
df.MaritalStatus.value_counts()
# We have more of married people using the product.
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %% [markdown]
# The MaritalStatus graph above explains the product distribution of customers based on their MaritalStatus. It shows both single and partnered customers actively use the product. It clearly explains that the Partnered with about 59.4% use the product more than the single.

# %% [markdown]
# # Graph showing Usage Visualization

# %%
labeled_barplot(df, "Usage", perc=True, n=None);

# %%
df.Usage.value_counts()
# Out:
# 3    69
# 4    52
# 2    33
# 5    17
# 6     7
# 7     2
# Name: Usage, dtype: int64

# %% [markdown]
# The Usage graph above explains the distribution of customers based on their Usage. Usage explains the number of times per week the customers use the products. As observed from the graph, customers use the product 3 times per week to 4 times on an average while the least number of days customers use the product is 6 times per week to 7 times. We can depict that customers don't really use the products 5 to 7 times per week.

# %% [markdown]
# # Graph showing Fitness Visualization

# %%
labeled_barplot(df, "Fitness", perc=False);

# %%
df.Fitness.value_counts()
# Out:
# 3    97
# 5    31
# 2    26
# 4    24
# 1     2
# Name: Fitness, dtype: int64

# %% [markdown]
# The Fitness graph above explains the distribution of customers based on their fitness. Fitness explains the self rate score input by customers as regarding how fit they are using the product. The fitness score 5 and 4 shows that the customers are very fit and cklosely fit while the score 1 and 2 shows that they are very unfit and closely unfit. As observed from the graph, customers tends to rate themselves score 3 the most which shows that they are fit with total number of about 97. Also, quite an average number of customers rated themselves as very fit and closely fit with a score of 4 and 5. It can be seen also that customers who rated themselves 1 as very unfit tends to be the lowest with total customers around 2. We can say from this observation that customers of this product are predominantly fit.

# %% [markdown]
# # Graph showing Income Visualization

# %%
sns.boxplot(x="Income", data=df);

# %%
df.Income.sum()
# Out:
# 9669524

# %%
df.Income.mean()
# Out:
# 53719.57777777778

# %%
df.Income.median()
# Out:
# 50596.5

# %%
df.Income.mode()
# Out:
# 0    45480
# Name: Income, dtype: int64

# %%
df.Income.va()
# Out:
# 45480    14
# 52302     9
# 46617     8
# 54576     8
# 53439     8
#          ..
# 65220     1
# 55713     1
# 68220     1
# 30699     1
# 95508     1
# Name: Income, Length: 62, dtype: int64

# %% [markdown]
# The Income graph above explains the distribution of customers based on their income. As observed from the graph, 25% of the customers income ranges from 30,000 to 45,000. 50 percentile of the customers earn between 43,000 to 50,000. 75 percentile of the customers earn between 50,000 to 60,000. There seems to be outliers within the range of incme 80,000 above. The bulk of customners earn within 43,000 to 60,000.

# %%
df.Income.min()
# Out:
# 29562

# %% [markdown]
# # Graph showing Miles Visualization

# %%
sns.histplot(x="Miles", data=df, kde=True );

# %%
df.Miles.sum()
# Out:
# 18575

# %%
df.Miles.mean()
# Out:
# 103.19444444444444

# %%
df.Miles.median()
# Out:
# 94.0

# %%
df.Miles.mode()
# Out:
# 0    85
# Name: Miles, dtype: int64

# %% [markdown]
# The Miles graph above explains the distribution of customers based on their miles covered. As observed from the graph, the mile graph is rightly skewed. The bulk of the customerscovered miles within the range of 50 miles to 120 miles. Larger percentage of the customers covered shorter miles.

# %% [markdown]
# # Bivarate Analysis

# %%
Cor=df.corr()

sns.heatmap(data=Cor, vmin=-1, vmax=1, annot=True, cmap="Spectral");
plt.figure(figsize=(10,10))
# Out:
# C:\Users\GBOLAHAN\AppData\Local\Temp\ipykernel_15288\2490814267.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Cor=df.corr()

# %% [markdown]
# The graph above explains the correlation between two feauters in our Datasets. As seen, features with positive relationships occurs within (Age and Income) which is averagely posititively related. (Education and Fitness) which is fairly positively related. (Education and Usage) which is fairly positively related. (Education and Income) which is averagely positively related. (Usage and Fitness) which is positively related as well as (Usage and Income). (Usage and Miles) seems to have a strong postitive relationship. (Fitness and Income) tends to be averagely positively related while (Fitness and Miles) are strongly positivey related. (Income and Miles) also tends to be averagely positively related.

# %%
sns.scatterplot(data=df, x="Income", y="Age")
# Out:
# <Axes: xlabel='Income', ylabel='Age'>

# %% [markdown]
# The graph above shows a scatterplot graph of Income and Age. It shows the distribution of Income of customers with their Age  This explicitly explains the relationship between Income and Age wwhere the higher the Age, the higher the Income the customer earns.

# %%
sns.scatterplot(data=df, x="Income", y="Miles")
# Out:
# <Axes: xlabel='Income', ylabel='Miles'>

# %% [markdown]
# The graph above shows a scatterplot graph of Income and Miles. It shows the distribution of Income of customers with the Miles covered. This explicitly explains the relationship between Income and Miles wwhere the higher the Income, the higher the Miles covered.

# %%
sns.scatterplot(data=df, x="Income", y="Education")
# Out:
# <Axes: xlabel='Income', ylabel='Education'>

# %% [markdown]
# The graph above shows a scatterplot graph of Income and Education. It shows the distribution of Income of customers with the Education of the product. This explicitly explains the relationship between Income and Education wwhere the higher the number of Education of the product, the higher the income earned. Thus, people with moreeducation earn earn more Income.

# %%
sns.catplot(data=df, x="Fitness", y="Miles", kind="box")

# %% [markdown]
# The graph above shows a categorical plot graph of Fitness and Miles. It shows the distribution of Miles covered of customers with their Fitness. This explicitly explains the relationship between Miles and Fitness wwhere the higher the number of Miles covered, the higher their fitness rating. Though with few outliers.

# %% [markdown]
# The graph above shows a categorical plot graph of Fitness and Miles. It shows the distribution of Miles covered of customers with their Fitness. This explicitly explains the relationship between Miles and Fitness wwhere the higher the number of Miles covered, the higher their fitness rating

# %%
sns.catplot(data=df, x="Fitness", y="Usage", kind="box")

# %% [markdown]
# The graph above shows a categorical plot graph of Fitness and Usage. It shows the distribution of usage of the product by customers with their Fitness. This explicitly explains the relationship between Usage and Miles wwhere the higher the number of usage, the higher their fitness rating.

# %%
sns.catplot(data=df, x="Product", y="Age", kind="box")

# %% [markdown]
# The graph above shows a categorical plot graph of Product and Age. It shows the distribution of Product and Age of customers. This explicitly explains the relationship between Age and the respective Products where for Product TM195,

# %%
sns.catplot(data=df, x="Product", y="Income", kind="box")

# %%
sns.catplot(data=df, x="Product", y="Usage", kind="box")

# %%
sns.catplot(data=df, x="Product", y="Fitness", kind="box")

# %%
sns.catplot(data=df, x="Product", y="Miles", kind="box")

# %%
sns.catplot(data=df, x="Product", y="Education", kind="box")

# %%
sns.catplot(data=df, x="Gender", y="Income", kind="box")

# %%
sns.catplot(data=df, x="Product", y="Income", kind="box")

# %%
sns.catplot(data=df, x="MaritalStatus", y="Income", kind="box")

# %%
sns.catplot(data=df, x="Usage", y="Income", kind="box")

# %%
sns.catplot(data=df, x="Fitness", y="Income", kind="box")

# %% [markdown]
# # Multivariate Analysis

# %%
sns.catplot(data=df, x="Product", y="Usage", kind="box", hue="Fitness")

# %% [markdown]
# The graph above explains the relationship between 3 features which are Product, Usage and Fitness. The three respective products include (TM195, TM498, TM798). Under Product TM195, the average number of times customers use this products lies from 2 to 5 times per week and their fitness score ranging from 2 to 5 also. For Product TM498, the average number of times customers use this products lies from 2 to 4 times per week and their fitness score ranging from 2 to 4 as well. For Product TM798, the average number of times customers use this products lies from 4 to 6 times per week and their fitness score ranging from 4 to 5 as well. This tells us alot about Product TM798 having the higher usage by customers. Thus, acing their fitness pace around 4 and 5. Customers who tend to use Product TM798 use it very well during the week, hence, increasing the fitness of the users to very fit and closely fit.

# %%
sns.catplot(data=df, x="Product", y="Education", kind="box", hue="Usage" )

# %% [markdown]
# The graph above explains the relationship between 3 features which are Product, Education and Usage. The three respective products include (TM195, TM498, TM798). Under Product TM195 and TM498, the Education of customers ranges from 14 to 16 as well as their usage being around 2 to 5. For Product TM798, the Education of customers ranges from 15 to 18 as well as their usage being around 4 to 7 times per week. As we have depicted earlier, Customers within 16 to 18 years of awareness tends to use the product the more. This also tell us more about Product TM789 in the category of having more number of customers who are largely about the product as well use the product 4 to 7 times per week when compared to other products.

# %%
sns.catplot(data=df, x="Product", y="Education", kind="box", hue="Fitness" )

# %% [markdown]
# The graph above explains the relationship between 3 features which are Product, Education and Fitness. The three respective products include (TM195, TM498, TM798). Under Product TM195 and TM498, the Education of customers ranges from 14 to 16 as well as their fitness score being around 2 to 4. For Product TM798, the Education of customers ranges from 16 to 18 as well as their fitness being around 3 to 5 times per week. As we have depicted earlier, Customers within 16 to 18 years of awareness tends to use the product the more. This also tell us more about Product TM789 in the category of having more number of customers who are largely aware about the product as well as the fitness of the customers falling around very fit and closely fit.

# %%
sns.catplot(data=df, x="Product", y="Income", kind="box", hue="Usage" )

# %% [markdown]
# The graph above explains the relationship between 3 features which are Product, Income and Usage. The three respective products include (TM195, TM498, TM798). Under Product TM195 and TM498, their customers income ranges around 35,000 to 55,000 and their usage being 2 to 5. For Product TM798, their cstomers

# %%
sns.catplot(data=df, x="Product", y="Income", kind="box", hue="Fitness" )

# %%
sns.catplot(data=df, x="Product", y="Income", kind="box", hue="Gender" )

# %%
sns.catplot(data=df, x="Product", y="Income", kind="box", hue="MaritalStatus" )

# %%
sns.catplot(data=df, x="Product", y="Income", kind="box", hue="Education" )

# %%
sns.catplot(data=df, x="Product", y="Education", kind="box", hue="Gender" )

# %%
sns.catplot(data=df, x="Product", y="Education", kind="box", hue="MaritalStatus" )

# %%
sns.catplot(data=df, x="Product", y="Miles", kind="box", hue="MaritalStatus" )

# %%
sns.catplot(data=df, x="Product", y="Miles", kind="box", hue="Education" )

# %%
sns.catplot(data=df, x="Product", y="Miles", kind="box", hue="Gender" )

# %%
sns.catplot(data=df, x="Product", y="Miles", kind="box", hue="Usage" )

# %%
sns.catplot(data=df, x="Product", y="Miles", kind="box", hue="Fitness" )

# %%
sns.catplot(data=df, x="Product", y="Age", kind="box", hue="Fitness" )

# %%
sns.catplot(data=df, x="Product", y="Age", kind="box", hue="Usage" )

# %%
sns.catplot(data=df, x="Product", y="Age", kind="box", hue="MaritalStatus" )

# %%
sns.catplot(data=df, x="Product", y="Age", kind="box", hue="Gender" )

# %%
sns.catplot(data=df, x="Product", y="Age", kind="box", hue="Education" )
